# %%
import torch
import json
import h5py
import random
import numpy as np
from matplotlib.pyplot import imshow
from PIL import Image, ImageDraw

# %%
# load the following to files from DETECTED_SGG_DIR
custom_prediction = json.load(open('/home/kaihua/checkpoints/test/custom_prediction.json'))
custom_data_info = json.load(open('/home/kaihua/checkpoints/test/custom_data_info.json'))

# %%
def draw_single_box(pic, box, color='red', draw_info=None):
    draw = ImageDraw.Draw(pic)
    x1,y1,x2,y2 = int(box[0]), int(box[1]), int(box[2]), int(box[3])
    draw.rectangle(((x1, y1), (x2, y2)), outline=color)
    if draw_info:
        draw.rectangle(((x1, y1), (x1+50, y1+10)), fill=color)
        info = draw_info
        draw.text((x1, y1), info)
        
def print_list(name, input_list, scores=None):
    for i, item in enumerate(input_list):
        if scores == None:
            print(name + ' ' + str(i) + ': ' + str(item))
        else:
            print(name + ' ' + str(i) + ': ' + str(item) + '; score: ' + str(scores[i]))
    
def draw_image(img_path, boxes, box_labels, rel_labels, box_scores=None, rel_scores=None):
    size = get_size(Image.open(img_path).size)
    pic = Image.open(img_path).resize(size)
    num_obj = len(boxes)
    for i in range(num_obj):
        info = str(i) + '_' + box_labels[i]
        draw_single_box(pic, boxes[i], draw_info=info)
    display(pic)
    print('*' * 50)
    print_list('box_labels', box_labels, box_scores)
    print('*' * 50)
    print_list('rel_labels', rel_labels, rel_scores)
    
    return None

def get_size(image_size):
    min_size = 600
    max_size = 1000
    w, h = image_size
    size = min_size
    if max_size is not None:
        min_original_size = float(min((w, h)))
        max_original_size = float(max((w, h)))
        if max_original_size / min_original_size * size > max_size:
            size = int(round(max_size * min_original_size / max_original_size))
    if (w <= h and w == size) or (h <= w and h == size):
        return (w, h)
    if w < h:
        ow = size
        oh = int(size * h / w)
    else:
        oh = size
        ow = int(size * w / h)
    return (ow, oh)

# %%
# parameters
image_idx = 3
box_topk = 10 # select top k bounding boxes
rel_topk = 20 # select top k relationships
ind_to_classes = custom_data_info['ind_to_classes']
ind_to_predicates = custom_data_info['ind_to_predicates']

# %%
image_path = custom_data_info['idx_to_files'][image_idx]
boxes = custom_prediction[str(image_idx)]['bbox'][:box_topk]
box_labels = custom_prediction[str(image_idx)]['bbox_labels'][:box_topk]
box_scores = custom_prediction[str(image_idx)]['bbox_scores'][:box_topk]
all_rel_labels = custom_prediction[str(image_idx)]['rel_labels']
all_rel_scores = custom_prediction[str(image_idx)]['rel_scores']
all_rel_pairs = custom_prediction[str(image_idx)]['rel_pairs']

for i in range(len(box_labels)):
    box_labels[i] = ind_to_classes[box_labels[i]]

rel_labels = []
rel_scores = []
for i in range(len(all_rel_pairs)):
    if all_rel_pairs[i][0] < box_topk and all_rel_pairs[i][1] < box_topk:
        rel_scores.append(all_rel_scores[i])
        label = str(all_rel_pairs[i][0]) + '_' + box_labels[all_rel_pairs[i][0]] + ' => ' + ind_to_predicates[all_rel_labels[i]] + ' => ' + str(all_rel_pairs[i][1]) + '_' + box_labels[all_rel_pairs[i][1]]
        rel_labels.append(label)

rel_labels = rel_labels[:rel_topk]
rel_scores = rel_scores[:rel_topk]

# %%
draw_image(image_path, boxes, box_labels, rel_labels, box_scores=box_scores, rel_scores=rel_scores)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7FF2741C99B0>
# **************************************************
# box_labels 0: woman; score: 0.8617894649505615
# box_labels 1: glass; score: 0.7646626830101013
# box_labels 2: glass; score: 0.691317081451416
# box_labels 3: hair; score: 0.5120436549186707
# box_labels 4: pant; score: 0.40522173047065735
# box_labels 5: clock; score: 0.38600945472717285
# box_labels 6: face; score: 0.3711170256137848
# box_labels 7: woman; score: 0.35884812474250793
# box_labels 8: shirt; score: 0.3311745524406433
# box_labels 9: face; score: 0.2790334224700928
# **************************************************
# rel_labels 0: 7_woman => has => 6_face; score: 0.7913535237312317
# rel_labels 1: 7_woman => wearing => 2_glass; score: 0.6907944679260254
# rel_labels 2: 0_woman => wearing => 4_pant; score: 0.6876915693283081
# rel_labels 3: 0_woman => wearing => 1_glass; score: 0.6733089685440063
# rel_labels 4: 0_woman => wearing => 8_shirt; score: 0.6575378775596619
# rel_labels 5: 7_woman => wearing => 4_pant; score: 0.6550156474113464
# rel_labels 6: 7_woman => wearing => 8_shirt; score: 0.6350440382957458
# rel_labels 7: 7_woman => wearing => 1_glass; score: 0.6165895462036133
# rel_labels 8: 0_woman => wearing => 2_glass; score: 0.6165394186973572
# rel_labels 9: 2_glass => on => 0_woman; score: 0.6129267811775208
# rel_labels 10: 1_glass => on => 7_woman; score: 0.5868139266967773
# rel_labels 11: 5_clock => above => 0_woman; score: 0.5617933869361877
# rel_labels 12: 0_woman => has => 6_face; score: 0.5471501350402832
# rel_labels 13: 6_face => of => 7_woman; score: 0.5334390997886658
# rel_labels 14: 9_face => of => 0_woman; score: 0.5254586935043335
# rel_labels 15: 4_pant => on => 7_woman; score: 0.5214910507202148
# rel_labels 16: 5_clock => above => 7_woman; score: 0.5187607407569885
# rel_labels 17: 6_face => of => 0_woman; score: 0.5185745358467102
# rel_labels 18: 8_shirt => wearing => 1_glass; score: 0.5166959166526794
# rel_labels 19: 8_shirt => wearing => 2_glass; score: 0.4976017475128174
